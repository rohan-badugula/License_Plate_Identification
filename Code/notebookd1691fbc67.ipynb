# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.31.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.9 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: numpy<1.24 in /opt/conda/lib/python3.10/site-packages (from pennylane) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from pennylane) (1.11.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from pennylane) (3.1)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 51.1 MB/s eta 0:00:00:00:01
# Collecting autograd<=1.5 (from pennylane)
#   Downloading autograd-1.5-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: toml in /opt/conda/lib/python3.10/site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in /opt/conda/lib/python3.10/site-packages (from pennylane) (1.4.4)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray<=0.6.3,>=0.3.1 (from pennylane)
#   Downloading autoray-0.6.3-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /opt/conda/lib/python3.10/site-packages (from pennylane) (4.2.4)
# Collecting pennylane-lightning>=0.31 (from pennylane)
#   Downloading PennyLane_Lightning-0.31.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 57.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from pennylane) (4.6.3)
# Requirement already satisfied: future>=0.15.2 in /opt/conda/lib/python3.10/site-packages (from autograd<=1.5->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->pennylane) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->pennylane) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->pennylane) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->pennylane) (2023.5.7)
# Installing collected packages: semantic-version, rustworkx, autoray, autograd, pennylane-lightning, pennylane
# Successfully installed autograd-1.5 autoray-0.6.3 pennylane-0.31.1 pennylane-lightning-0.31.0 rustworkx-0.13.1 semantic-version-2.10.0

# %%
import pennylane as qml
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pennylane as qml
#
# File /opt/conda/lib/python3.10/site-packages/pennylane/__init__.py:125
#     122 import pennylane.qinfo  # pylint:disable=wrong-import-order
#     123 from pennylane.interfaces import execute  # pylint:disable=wrong-import-order
# --> 125 import pennylane.data
#     127 # Look for an existing configuration file
#     128 default_config = Configuration("config.toml")
#
# File /opt/conda/lib/python3.10/site-packages/pennylane/data/__init__.py:197
#       1 # Copyright 2018-2023 Xanadu Quantum Technologies Inc.
#       2
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      14 """The data subpackage provides functionality to access, store and manipulate `quantum datasets <https://pennylane.ai/qml/datasets.html>`_.
#      15
#      16 .. note::
#    (...)
#     194
#     195 """
# --> 197 from .attributes import (
#     198     DatasetArray,
#     199     DatasetDict,
#     200     DatasetJSON,
#     201     DatasetList,
#     202     DatasetMolecule,
#     203     DatasetNone,
#     204     DatasetOperator,
#     205     DatasetScalar,
#     206     DatasetSparseArray,
#     207     DatasetString,
#     208     DatasetTuple,
#     209 )
#     210 from .base import DatasetNotWriteableError
#     211 from .base.attribute import AttributeInfo, DatasetAttribute, attribute
#
# File /opt/conda/lib/python3.10/site-packages/pennylane/data/attributes/__init__.py:24
#      22 from .operator import DatasetOperator
#      23 from .scalar import DatasetScalar
# ---> 24 from .sparse_array import DatasetSparseArray
#      25 from .string import DatasetString
#      26 from .tuple import DatasetTuple
#
# File /opt/conda/lib/python3.10/site-packages/pennylane/data/attributes/sparse_array.py:20
#      17 from typing import Dict, Generic, Tuple, Type, TypeVar, Union, cast
#      19 import numpy as np
# ---> 20 from scipy.sparse import (
#      21     bsr_array,
#      22     bsr_matrix,
#      23     coo_array,
#      24     coo_matrix,
#      25     csc_array,
#      26     csc_matrix,
#      27     csr_array,
#      28     csr_matrix,
#      29     dia_array,
#      30     dia_matrix,
#      31     dok_array,
#      32     dok_matrix,
#      33     lil_array,
#      34     lil_matrix,
#      35 )
#      37 from pennylane.data.base.attribute import AttributeInfo, DatasetAttribute
#      38 from pennylane.data.base.hdf5 import HDF5Group
#
# ImportError: cannot import name 'bsr_array' from 'scipy.sparse' (/opt/conda/lib/python3.10/site-packages/scipy/sparse/__init__.py)
